# %%
#QUESTION 1
import numpy as ny
x=ny.random.rand(10,1)
print(x)
# Out:
# [[0.71682245]
#  [0.97938976]
#  [0.1974716 ]
#  [0.27139106]
#  [0.71586327]
#  [0.25171847]
#  [0.38899907]
#  [0.00447793]
#  [0.73764469]
#  [0.02756992]]

# %%
print("Mean : ",x.mean())
# Out:
# Mean :  0.4291348213961716

# %%
#QUESTION 2
y=ny.random.rand(20,1)
print("Variance : ",y.var())
# Out:
# Variance :  0.10741187398392922

# %%
print("Standard deviation : ",y.std())
# Out:
# Standard deviation :  0.3277375077465642

# %%
#QUESTION 3 
a=ny.random.rand(10,20)
b=ny.random.rand(20,25)
c=ny.matmul(a,b)
print("Matrix Multiplication")
print(c)
# Out:
# Matrix Multiplication
# [[5.37002408 5.70162503 6.64140336 6.00261284 6.58355223 5.47378033
#   5.30850041 7.97962315 7.57342775 6.36228471 6.60910291 5.14282848
#   6.13792714 6.1558601  5.98905458 5.80578839 5.85514438 5.39359106
#   7.18947372 6.3537015  6.11553532 6.46721653 4.57302144 7.20598381
#   5.1011628 ]
#  [4.69678565 6.09294465 5.89262041 5.76236506 6.25937478 5.14477562
#   4.26501579 8.03575398 7.064973   5.17055932 6.02961383 5.31733802
#   5.3155236  6.18426334 5.29301249 3.71666516 5.01627997 5.11083661
#   5.48034251 5.62171588 5.34319792 4.82389978 3.83660033 5.83194309
#   4.96569246]
#  [3.41795615 5.00138451 4.9621087  4.88271832 5.51280531 5.15530932
#   4.27854173 6.81109004 6.58984996 5.15458269 5.37246585 4.94707528
#   4.59767526 4.75943117 5.5766612  4.65890718 4.59011762 3.86193703
#   5.05083105 4.99909377 5.29046927 4.826225   3.64699147 5.67749482
#   4.2243873 ]
#  [4.53069332 5.11898891 5.15352571 4.82886271 5.66338826 4.40969372
# ...

# %%
print(c.shape)
# Out:
# (10, 25)

# %%
print("sum of all elements : ",ny.sum(c))
# Out:
# sum of all elements :  1283.8635530718636

# %%
#QUESTION 4
A=ny.random.rand(10,1)
print(A)
# Out:
# [[0.28314658]
#  [0.49671692]
#  [0.08774647]
#  [0.56340586]
#  [0.4702158 ]
#  [0.91268241]
#  [0.74084182]
#  [0.97462064]
#  [0.64131023]
#  [0.53915147]]

# %%
import math
def func(x):
    y=1 / (1 + math.exp(-x))
    return y
res=list(map(func,A))
#print(res)
print(ny.array(res))
# Out:
# [0.57031748 0.62168748 0.52192255 0.63724022 0.61543483 0.71354875
#  0.67717991 0.72603953 0.65504958 0.63161501]
